# %%
# Update sklearn to prevent version mismatches
# !pip install sklearn --upgrade
# Out:
# Requirement already up-to-date: sklearn in c:\users\hanie\anaconda3\lib\site-packages (0.0)
# Requirement already satisfied, skipping upgrade: scikit-learn in c:\users\hanie\anaconda3\lib\site-packages (from sklearn) (0.23.1)
# Requirement already satisfied, skipping upgrade: threadpoolctl>=2.0.0 in c:\users\hanie\anaconda3\lib\site-packages (from scikit-learn->sklearn) (2.1.0)
# Requirement already satisfied, skipping upgrade: numpy>=1.13.3 in c:\users\hanie\anaconda3\lib\site-packages (from scikit-learn->sklearn) (1.18.5)
# Requirement already satisfied, skipping upgrade: scipy>=0.19.1 in c:\users\hanie\anaconda3\lib\site-packages (from scikit-learn->sklearn) (1.5.0)
# Requirement already satisfied, skipping upgrade: joblib>=0.11 in c:\users\hanie\anaconda3\lib\site-packages (from scikit-learn->sklearn) (0.16.0)

# %%
# install joblib. This will be used to save your model. 
# Restart your kernel after installing 
# !pip install joblib
# Out:
# Requirement already satisfied: joblib in c:\users\hanie\anaconda3\lib\site-packages (0.16.0)

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.preprocessing import LabelEncoder, MinMaxScaler
from sklearn.feature_selection import RFECV
from sklearn import tree
import joblib

# %% [markdown]
# # Read the CSV and Perform Basic Data Cleaning

# %%
df = pd.read_csv("exoplanet_data.csv")
# Drop the null columns where all values are null
df = df.dropna(axis='columns', how='all')
# Drop the null rows
df = df.dropna()
df.head()
# Out:
#   koi_disposition  koi_fpflag_nt  koi_fpflag_ss  koi_fpflag_co  koi_fpflag_ec  \
# 0       CONFIRMED              0              0              0              0
# 1  FALSE POSITIVE              0              1              0              0
# 2  FALSE POSITIVE              0              1              0              0
# 3       CONFIRMED              0              0              0              0
# 4       CONFIRMED              0              0              0              0
#
#    koi_period  koi_period_err1  koi_period_err2  koi_time0bk  \
# 0   54.418383     2.479000e-04    -2.479000e-04   162.513840
# 1   19.899140     1.490000e-05    -1.490000e-05   175.850252
# 2    1.736952     2.630000e-07    -2.630000e-07   170.307565
# 3    2.525592     3.760000e-06    -3.760000e-06   171.595550
# 4    4.134435     1.050000e-05    -1.050000e-05   172.979370
#
#    koi_time0bk_err1  ...  koi_steff_err2  koi_slogg  koi_slogg_err1  \
# 0          0.003520  ...             -81      4.467           0.064
# 1          0.000581  ...            -176      4.544           0.044
# 2          0.000115  ...            -174      4.564           0.053
# 3          0.001130  ...            -211      4.438           0.070
# 4          0.001900  ...            -232      4.486           0.054
#
#    koi_slogg_err2  koi_srad  koi_srad_err1  koi_srad_err2         ra  \
# 0          -0.096     0.927          0.105         -0.061  291.93423
# 1          -0.176     0.868          0.233         -0.078  297.00482
# 2          -0.168     0.791          0.201         -0.067  285.53461
# 3          -0.210     1.046          0.334         -0.133  288.75488
# 4          -0.229     0.972          0.315         -0.105  296.28613
#
#          dec  koi_kepmag
# 0  48.141651      15.347
# 1  48.134129      15.436
# 2  48.285210      15.597
# 3  48.226200      15.509
# 4  48.224670      15.714
#
# [5 rows x 41 columns]

# %%
df["koi_disposition"].value_counts()
# Out:
# FALSE POSITIVE    3504
# CONFIRMED         1800
# CANDIDATE         1687
# Name: koi_disposition, dtype: int64

# %%
from sklearn.preprocessing import OneHotEncoder

# %%
import numpy as np
from sklearn.preprocessing import OneHotEncoder
# creating instance of one-hot-encoder
enc = OneHotEncoder(handle_unknown='ignore')
# passing bridge-types-cat column (label encoded values of bridge_types)
enc_df = pd.DataFrame(enc.fit_transform(df[['koi_disposition']]).toarray())
# merge with main df bridge_df on key values
final_df = df.join(enc_df)
final_df
# Out:
#      koi_disposition  koi_fpflag_nt  koi_fpflag_ss  koi_fpflag_co  \
# 0          CONFIRMED              0              0              0
# 1     FALSE POSITIVE              0              1              0
# 2     FALSE POSITIVE              0              1              0
# 3          CONFIRMED              0              0              0
# 4          CONFIRMED              0              0              0
# ...              ...            ...            ...            ...
# 6986  FALSE POSITIVE              0              0              0
# 6987  FALSE POSITIVE              0              1              1
# 6988       CANDIDATE              0              0              0
# 6989  FALSE POSITIVE              0              0              1
# 6990  FALSE POSITIVE              0              0              1
#
#       koi_fpflag_ec  koi_period  koi_period_err1  koi_period_err2  \
# 0                 0   54.418383     2.479000e-04    -2.479000e-04
# 1                 0   19.899140     1.490000e-05    -1.490000e-05
# 2                 0    1.736952     2.630000e-07    -2.630000e-07
# 3                 0    2.525592     3.760000e-06    -3.760000e-06
# 4                 0    4.134435     1.050000e-05    -1.050000e-05
# ...             ...         ...              ...              ...
# 6986              1    8.589871     1.846000e-04    -1.846000e-04
# 6987              0    0.527699     1.160000e-07    -1.160000e-07
# 6988              0    1.739849     1.780000e-05    -1.780000e-05
# 6989              0    0.681402     2.430000e-06    -2.430000e-06
# 6990              1    4.856035     6.360000e-05    -6.360000e-05
#
#       koi_time0bk  koi_time0bk_err1  ...  koi_slogg_err2  koi_srad  \
# 0      162.513840          0.003520  ...          -0.096     0.927
# 1      175.850252          0.000581  ...          -0.176     0.868
# 2      170.307565          0.000115  ...          -0.168     0.791
# 3      171.595550          0.001130  ...          -0.210     1.046
# 4      172.979370          0.001900  ...          -0.229     0.972
# ...           ...               ...  ...             ...       ...
# 6986   132.016100          0.015700  ...          -0.189     1.088
# 6987   131.705093          0.000170  ...          -0.196     0.903
# 6988   133.001270          0.007690  ...          -0.224     1.031
# 6989   132.181750          0.002850  ...          -0.224     1.041
# 6990   135.993300          0.010800  ...          -0.216     1.193
#
#       koi_srad_err1  koi_srad_err2         ra        dec  koi_kepmag    0  \
# 0             0.105         -0.061  291.93423  48.141651      15.347  0.0
# 1             0.233         -0.078  297.00482  48.134129      15.436  0.0
# 2             0.201         -0.067  285.53461  48.285210      15.597  0.0
# 3             0.334         -0.133  288.75488  48.226200      15.509  0.0
# 4             0.315         -0.105  296.28613  48.224670      15.714  0.0
# ...             ...            ...        ...        ...         ...  ...
# 6986          0.313         -0.228  298.74921  46.973351      14.478  0.0
# 6987          0.237         -0.079  297.18875  47.093819      14.082  0.0
# 6988          0.341         -0.114  286.50937  47.163219      14.757  1.0
# 6989          0.341         -0.114  294.16489  47.176281      15.385  0.0
# 6990          0.410         -0.137  297.00977  47.121021      14.826  0.0
#
#         1    2
# 0     1.0  0.0
# 1     0.0  1.0
# 2     0.0  1.0
# 3     1.0  0.0
# 4     1.0  0.0
# ...   ...  ...
# 6986  0.0  1.0
# 6987  0.0  1.0
# 6988  0.0  0.0
# 6989  0.0  1.0
# 6990  0.0  1.0
#
# [6991 rows x 44 columns]

# %%
#Use `koi_disposition` for the y values
X=df.drop("koi_disposition", axis=1)
feature_names = X.columns
y=df["koi_disposition"]

def functionrand(x):
    if x == 'CONFIRMED':
        return 1
    else:
        return 0
y = y.apply(functionrand)
y[:5]
# Out:
# 0    1
# 1    0
# 2    0
# 3    1
# 4    1
# Name: koi_disposition, dtype: int64

# %%
# Split data into training and testing groups
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=42)

# %%
# Scale your data
X_scaler = MinMaxScaler().fit(X_train)
X_train_scaled = X_scaler.transform(X_train)
X_test_scaled = X_scaler.transform(X_test)

# %%
from sklearn.ensemble import RandomForestClassifier
rf = RandomForestClassifier(n_estimators=200)
rf = rf.fit(X_train_scaled, y_train)
rf.score(X_test_scaled, y_test)
# Out:
# 0.902745995423341

# %%
#get the importance of features to use it in other models 
sorted(zip(rf.feature_importances_, feature_names), reverse=True)
# Out:
# [(0.06709857836424121, 'koi_steff_err1'),
#  (0.06379631228099256, 'koi_model_snr'),
#  (0.0561919315875524, 'koi_duration_err2'),
#  (0.05555394365290301, 'koi_steff_err2'),
#  (0.050215285268467864, 'koi_duration_err1'),
#  (0.04901961215731213, 'koi_prad'),
#  (0.0461259002766264, 'koi_fpflag_co'),
#  (0.03804248323938661, 'koi_prad_err1'),
#  (0.033709751979751644, 'koi_time0bk_err1'),
#  (0.033302264157192736, 'koi_time0bk_err2'),
#  (0.02981419929162731, 'koi_prad_err2'),
#  (0.02887647074714393, 'koi_fpflag_ss'),
#  (0.027752561481820502, 'koi_impact'),
#  (0.02656671460099259, 'koi_duration'),
#  (0.02518430400465258, 'koi_period'),
#  (0.02140282663140696, 'koi_depth'),
#  (0.021145910256368663, 'koi_srad_err1'),
#  (0.02064088766738196, 'koi_insol_err1'),
#  (0.018132492889542617, 'koi_depth_err2'),
#  (0.01784700746972937, 'koi_slogg_err2'),
#  (0.017461198851196194, 'koi_depth_err1'),
#  (0.017158222806315387, 'koi_time0bk'),
#  (0.0170206622742236, 'koi_period_err1'),
#  (0.01696051652594476, 'koi_teq'),
#  (0.016356500850618075, 'koi_period_err2'),
#  (0.015891561902191872, 'ra'),
#  (0.01550830817091336, 'dec'),
#  (0.015482713092802847, 'koi_impact_err2'),
#  (0.015150136652498848, 'koi_insol'),
#  (0.014928203901326034, 'koi_kepmag'),
#  (0.01480494470961024, 'koi_insol_err2'),
#  (0.014082302458752036, 'koi_impact_err1'),
#  (0.012772354375254823, 'koi_slogg'),
#  (0.012137560359195112, 'koi_steff'),
#  (0.012118234254620218, 'koi_srad_err2'),
#  (0.011944295551094964, 'koi_srad'),
#  (0.011061065508345118, 'koi_slogg_err1'),
#  (0.008746925561536174, 'koi_fpflag_ec'),
#  (0.005577881650775065, 'koi_fpflag_nt'),
#  (0.004416972537692248, 'koi_tce_plnt_num')]

# %%
print(f"Training Data Score: {rf.score(X_train_scaled, y_train)}")
print(f"Testing Data Score: {rf.score(X_test_scaled, y_test)}")
# Out:
# Training Data Score: 1.0
# Testing Data Score: 0.902745995423341

# %%
from sklearn.tree import export_graphviz

# %%
from matplotlib import pyplot as plt

# %%
plt.figure(figsize=(20,20))
_ = tree.plot_tree(rf.estimators_[0], feature_names=X_train.columns, filled=True)

# %%
X_train
# Out:
#       koi_fpflag_nt  koi_fpflag_ss  koi_fpflag_co  koi_fpflag_ec  koi_period  \
# 6122              0              0              0              0    6.768901
# 6370              0              1              0              1    0.733726
# 2879              1              0              0              0    7.652707
# 107               0              0              0              0    7.953547
# 29                0              0              0              0    4.959319
# ...             ...            ...            ...            ...         ...
# 3772              0              1              0              0    8.268081
# 5191              0              0              0              0   11.161938
# 5226              0              1              0              0    6.150251
# 5390              1              0              0              0    3.343285
# 860               0              0              1              0    2.271907
#
#       koi_period_err1  koi_period_err2  koi_time0bk  koi_time0bk_err1  \
# 6122     7.380000e-05    -7.380000e-05   133.077240          0.008440
# 6370     6.060000e-06    -6.060000e-06   132.020050          0.007950
# 2879     6.540000e-05    -6.540000e-05   134.460380          0.006190
# 107      1.910000e-05    -1.910000e-05   174.662240          0.001820
# 29       5.150000e-07    -5.150000e-07   172.258529          0.000083
# ...               ...              ...          ...               ...
# 3772     6.340000e-07    -6.340000e-07   135.056330          0.000064
# 5191     1.677000e-04    -1.677000e-04   133.553800          0.013000
# 5226     7.000000e-07    -7.000000e-07   134.422825          0.000088
# 5390     4.380000e-05    -4.380000e-05   134.845100          0.011200
# 860      1.300000e-05    -1.300000e-05   134.798520          0.004670
#
#       koi_time0bk_err2  ...  koi_steff_err2  koi_slogg  koi_slogg_err1  \
# 6122         -0.008440  ...            -171      4.327           0.153
# 6370         -0.007950  ...            -175      4.578           0.033
# 2879         -0.006190  ...            -189      4.481           0.050
# 107          -0.001820  ...             -85      4.536           0.056
# 29           -0.000083  ...             -77      4.359           0.110
# ...                ...  ...             ...        ...             ...
# 3772         -0.000064  ...            -190      4.502           0.050
# 5191         -0.013000  ...            -124      4.072           0.188
# 5226         -0.000088  ...            -458      3.896           0.270
# 5390         -0.011200  ...            -197      3.773           0.293
# 860          -0.004670  ...            -155      4.506           0.072
#
#       koi_slogg_err2  koi_srad  koi_srad_err1  koi_srad_err2         ra  \
# 6122          -0.187     1.125          0.310         -0.207  294.40472
# 6370          -0.187     0.797          0.211         -0.056  284.50391
# 2879          -0.200     0.963          0.290         -0.097  295.50211
# 107           -0.016     0.779          0.023         -0.049  291.15878
# 29            -0.110     1.082          0.173         -0.130  292.16705
# ...              ...       ...            ...            ...        ...
# 3772          -0.200     0.922          0.273         -0.091  292.53125
# 5191          -0.101     1.640          0.281         -0.343  295.21268
# 5226          -0.180     2.867          0.988         -1.087  297.18176
# 5390          -0.098     2.652          0.433         -0.939  296.86258
# 860           -0.168     0.856          0.225         -0.096  294.73419
#
#             dec  koi_kepmag
# 6122  39.351681      14.725
# 6370  42.463860      15.770
# 2879  38.983540      13.099
# 107   40.750271      15.660
# 29    48.727589      15.263
# ...         ...         ...
# 3772  46.728699      15.768
# 5191  49.562180      13.374
# 5226  45.988441      10.622
# 5390  41.147419      13.276
# 860   40.861420      14.459
#
# [5243 rows x 40 columns]

# %%
rf.estimators_[0].tree_.max_depth
# Out:
# 32

# %%
rf_3 = RandomForestClassifier(n_estimators=100, max_depth=5)
rf_3.fit(X_train, y_train)
# Out:
# RandomForestClassifier(max_depth=5)

# %%
plt.figure(figsize=(25,25))
_ = tree.plot_tree(rf_3.estimators_[0], feature_names=X_train.columns, filled=True)

# %% [markdown]
# # Hyperparameter Tuning
#
# Use `GridSearchCV` to tune the model's parameters

# %%
# Support vector machine linear classifier
from sklearn.svm import SVC 
model = SVC(kernel='linear')

# %%
# Create the GridSearchCV model
from sklearn.model_selection import GridSearchCV
param_grid = {'min_samples_split': [3, 5],
              'n_estimators': [100, 200],
             'max_depth':[6, 8, 10]}
grid = GridSearchCV(rf, param_grid, verbose=3)

# %%
# Train the model with GridSearch
# Fit the model using the grid search estimator. 
# This will take the SVC model and try each combination of parameters
grid.fit(X_train_scaled, y_train)
# Out:
# Fitting 5 folds for each of 12 candidates, totalling 60 fits
# [CV] max_depth=6, min_samples_split=3, n_estimators=100 ..............
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [CV]  max_depth=6, min_samples_split=3, n_estimators=100, score=0.895, total=   0.9s
# [CV] max_depth=6, min_samples_split=3, n_estimators=100 ..............
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.8s remaining:    0.0s
# [CV]  max_depth=6, min_samples_split=3, n_estimators=100, score=0.896, total=   1.0s
# [CV] max_depth=6, min_samples_split=3, n_estimators=100 ..............
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:    1.7s remaining:    0.0s
# [CV]  max_depth=6, min_samples_split=3, n_estimators=100, score=0.894, total=   1.0s
# [CV] max_depth=6, min_samples_split=3, n_estimators=100 ..............
# [CV]  max_depth=6, min_samples_split=3, n_estimators=100, score=0.881, total=   0.9s
# [CV] max_depth=6, min_samples_split=3, n_estimators=100 ..............
# [CV]  max_depth=6, min_samples_split=3, n_estimators=100, score=0.876, total=   0.9s
# [CV] max_depth=6, min_samples_split=3, n_estimators=200 ..............
# [CV]  max_depth=6, min_samples_split=3, n_estimators=200, score=0.904, total=   1.8s
# [CV] max_depth=6, min_samples_split=3, n_estimators=200 ..............
# [CV]  max_depth=6, min_samples_split=3, n_estimators=200, score=0.899, total=   1.7s
# [CV] max_depth=6, min_samples_split=3, n_estimators=200 ..............
# [CV]  max_depth=6, min_samples_split=3, n_estimators=200, score=0.894, total=   2.0s
# [CV] max_depth=6, min_samples_split=3, n_estimators=200 ..............
# [CV]  max_depth=6, min_samples_split=3, n_estimators=200, score=0.888, total=   1.8s
# [CV] max_depth=6, min_samples_split=3, n_estimators=200 ..............
# [CV]  max_depth=6, min_samples_split=3, n_estimators=200, score=0.872, total=   1.9s
# [CV] max_depth=6, min_samples_split=5, n_estimators=100 ..............
# [CV]  max_depth=6, min_samples_split=5, n_estimators=100, score=0.893, total=   0.9s
# [CV] max_depth=6, min_samples_split=5, n_estimators=100 ..............
# [CV]  max_depth=6, min_samples_split=5, n_estimators=100, score=0.892, total=   0.9s
# [CV] max_depth=6, min_samples_split=5, n_estimators=100 ..............
# [CV]  max_depth=6, min_samples_split=5, n_estimators=100, score=0.891, total=   0.9s
# [CV] max_depth=6, min_samples_split=5, n_estimators=100 ..............
# [CV]  max_depth=6, min_samples_split=5, n_estimators=100, score=0.886, total=   1.0s
# [CV] max_depth=6, min_samples_split=5, n_estimators=100 ..............
# [CV]  max_depth=6, min_samples_split=5, n_estimators=100, score=0.877, total=   1.0s
# [CV] max_depth=6, min_samples_split=5, n_estimators=200 ..............
# [CV]  max_depth=6, min_samples_split=5, n_estimators=200, score=0.899, total=   1.7s
# [CV] max_depth=6, min_samples_split=5, n_estimators=200 ..............
# [CV]  max_depth=6, min_samples_split=5, n_estimators=200, score=0.894, total=   2.1s
# [CV] max_depth=6, min_samples_split=5, n_estimators=200 ..............
# [CV]  max_depth=6, min_samples_split=5, n_estimators=200, score=0.894, total=   1.9s
# [CV] max_depth=6, min_samples_split=5, n_estimators=200 ..............
# [CV]  max_depth=6, min_samples_split=5, n_estimators=200, score=0.885, total=   1.7s
# [CV] max_depth=6, min_samples_split=5, n_estimators=200 ..............
# [CV]  max_depth=6, min_samples_split=5, n_estimators=200, score=0.878, total=   1.8s
# [CV] max_depth=8, min_samples_split=3, n_estimators=100 ..............
# [CV]  max_depth=8, min_samples_split=3, n_estimators=100, score=0.904, total=   1.1s
# [CV] max_depth=8, min_samples_split=3, n_estimators=100 ..............
# [CV]  max_depth=8, min_samples_split=3, n_estimators=100, score=0.900, total=   1.0s
# [CV] max_depth=8, min_samples_split=3, n_estimators=100 ..............
# [CV]  max_depth=8, min_samples_split=3, n_estimators=100, score=0.897, total=   1.1s
# [CV] max_depth=8, min_samples_split=3, n_estimators=100 ..............
# [CV]  max_depth=8, min_samples_split=3, n_estimators=100, score=0.896, total=   1.1s
# [CV] max_depth=8, min_samples_split=3, n_estimators=100 ..............
# [CV]  max_depth=8, min_samples_split=3, n_estimators=100, score=0.881, total=   1.0s
# [CV] max_depth=8, min_samples_split=3, n_estimators=200 ..............
# [CV]  max_depth=8, min_samples_split=3, n_estimators=200, score=0.907, total=   1.8s
# [CV] max_depth=8, min_samples_split=3, n_estimators=200 ..............
# [CV]  max_depth=8, min_samples_split=3, n_estimators=200, score=0.905, total=   1.9s
# [CV] max_depth=8, min_samples_split=3, n_estimators=200 ..............
# [CV]  max_depth=8, min_samples_split=3, n_estimators=200, score=0.902, total=   2.1s
# [CV] max_depth=8, min_samples_split=3, n_estimators=200 ..............
# [CV]  max_depth=8, min_samples_split=3, n_estimators=200, score=0.896, total=   2.2s
# [CV] max_depth=8, min_samples_split=3, n_estimators=200 ..............
# [CV]  max_depth=8, min_samples_split=3, n_estimators=200, score=0.880, total=   2.3s
# [CV] max_depth=8, min_samples_split=5, n_estimators=100 ..............
# [CV]  max_depth=8, min_samples_split=5, n_estimators=100, score=0.908, total=   1.1s
# [CV] max_depth=8, min_samples_split=5, n_estimators=100 ..............
# [CV]  max_depth=8, min_samples_split=5, n_estimators=100, score=0.906, total=   1.0s
# [CV] max_depth=8, min_samples_split=5, n_estimators=100 ..............
# [CV]  max_depth=8, min_samples_split=5, n_estimators=100, score=0.902, total=   1.1s
# [CV] max_depth=8, min_samples_split=5, n_estimators=100 ..............
# [CV]  max_depth=8, min_samples_split=5, n_estimators=100, score=0.898, total=   1.1s
# [CV] max_depth=8, min_samples_split=5, n_estimators=100 ..............
# [CV]  max_depth=8, min_samples_split=5, n_estimators=100, score=0.884, total=   1.0s
# [CV] max_depth=8, min_samples_split=5, n_estimators=200 ..............
# [CV]  max_depth=8, min_samples_split=5, n_estimators=200, score=0.903, total=   1.9s
# [CV] max_depth=8, min_samples_split=5, n_estimators=200 ..............
# [CV]  max_depth=8, min_samples_split=5, n_estimators=200, score=0.904, total=   1.9s
# [CV] max_depth=8, min_samples_split=5, n_estimators=200 ..............
# [CV]  max_depth=8, min_samples_split=5, n_estimators=200, score=0.899, total=   2.1s
# [CV] max_depth=8, min_samples_split=5, n_estimators=200 ..............
# [CV]  max_depth=8, min_samples_split=5, n_estimators=200, score=0.897, total=   2.0s
# [CV] max_depth=8, min_samples_split=5, n_estimators=200 ..............
# [CV]  max_depth=8, min_samples_split=5, n_estimators=200, score=0.880, total=   2.1s
# [CV] max_depth=10, min_samples_split=3, n_estimators=100 .............
# [CV]  max_depth=10, min_samples_split=3, n_estimators=100, score=0.908, total=   1.1s
# [CV] max_depth=10, min_samples_split=3, n_estimators=100 .............
# [CV]  max_depth=10, min_samples_split=3, n_estimators=100, score=0.908, total=   1.1s
# [CV] max_depth=10, min_samples_split=3, n_estimators=100 .............
# [CV]  max_depth=10, min_samples_split=3, n_estimators=100, score=0.899, total=   1.0s
# [CV] max_depth=10, min_samples_split=3, n_estimators=100 .............
# [CV]  max_depth=10, min_samples_split=3, n_estimators=100, score=0.891, total=   1.0s
# [CV] max_depth=10, min_samples_split=3, n_estimators=100 .............
# [CV]  max_depth=10, min_samples_split=3, n_estimators=100, score=0.883, total=   1.0s
# [CV] max_depth=10, min_samples_split=3, n_estimators=200 .............
# [CV]  max_depth=10, min_samples_split=3, n_estimators=200, score=0.908, total=   2.2s
# [CV] max_depth=10, min_samples_split=3, n_estimators=200 .............
# [CV]  max_depth=10, min_samples_split=3, n_estimators=200, score=0.906, total=   2.0s
# [CV] max_depth=10, min_samples_split=3, n_estimators=200 .............
# [CV]  max_depth=10, min_samples_split=3, n_estimators=200, score=0.900, total=   2.0s
# [CV] max_depth=10, min_samples_split=3, n_estimators=200 .............
# [CV]  max_depth=10, min_samples_split=3, n_estimators=200, score=0.900, total=   2.0s
# [CV] max_depth=10, min_samples_split=3, n_estimators=200 .............
# [CV]  max_depth=10, min_samples_split=3, n_estimators=200, score=0.885, total=   2.1s
# [CV] max_depth=10, min_samples_split=5, n_estimators=100 .............
# [CV]  max_depth=10, min_samples_split=5, n_estimators=100, score=0.907, total=   1.0s
# [CV] max_depth=10, min_samples_split=5, n_estimators=100 .............
# [CV]  max_depth=10, min_samples_split=5, n_estimators=100, score=0.900, total=   1.0s
# [CV] max_depth=10, min_samples_split=5, n_estimators=100 .............
# [CV]  max_depth=10, min_samples_split=5, n_estimators=100, score=0.900, total=   1.1s
# [CV] max_depth=10, min_samples_split=5, n_estimators=100 .............
# [CV]  max_depth=10, min_samples_split=5, n_estimators=100, score=0.900, total=   1.0s
# [CV] max_depth=10, min_samples_split=5, n_estimators=100 .............
# [CV]  max_depth=10, min_samples_split=5, n_estimators=100, score=0.887, total=   1.1s
# [CV] max_depth=10, min_samples_split=5, n_estimators=200 .............
# [CV]  max_depth=10, min_samples_split=5, n_estimators=200, score=0.908, total=   2.2s
# [CV] max_depth=10, min_samples_split=5, n_estimators=200 .............
# [CV]  max_depth=10, min_samples_split=5, n_estimators=200, score=0.902, total=   2.1s
# [CV] max_depth=10, min_samples_split=5, n_estimators=200 .............
# [CV]  max_depth=10, min_samples_split=5, n_estimators=200, score=0.903, total=   2.0s
# [CV] max_depth=10, min_samples_split=5, n_estimators=200 .............
# [CV]  max_depth=10, min_samples_split=5, n_estimators=200, score=0.898, total=   2.0s
# [CV] max_depth=10, min_samples_split=5, n_estimators=200 .............
# [CV]  max_depth=10, min_samples_split=5, n_estimators=200, score=0.885, total=   2.0s
# [Parallel(n_jobs=1)]: Done  60 out of  60 | elapsed:  1.5min finished
# GridSearchCV(estimator=RandomForestClassifier(n_estimators=200),
#              param_grid={'max_depth': [6, 8, 10], 'min_samples_split': [3, 5],
#                          'n_estimators': [100, 200]},
#              verbose=3)

# %%
print(grid.best_params_)
print(grid.best_score_)
# Out:
# {'max_depth': 10, 'min_samples_split': 3, 'n_estimators': 200}
# 0.8998637379110603

# %%
rf_final= RandomForestClassifier(n_estimators=100, max_depth=6, min_samples_split=5)
rf_final.fit(X_train_scaled, y_train)
# Out:
# RandomForestClassifier(max_depth=6, min_samples_split=5)

# %%
rf_final.score(X_test_scaled, y_test)
# Out:
# 0.8861556064073226

# %% [markdown]
# # Save the Model

# %%
# save your model by updating "your_name" with your name
# and "your_model" with your model variable
# be sure to turn this in to BCS
# if joblib fails to import, try running the command to install in terminal/git-bash
import joblib
filename = 'your_name.sav'
joblib.dump(your_model, filename)
